# %% [markdown]
# # learning SQL

# %% [markdown]
# ## Conceptos Básicos

# %% [markdown]
# #### Tablas de base de datos
# Una tabla almacena y muestra datos en un formato estructurado que consta de columnas y filas que son similares a las que se ven en las hojas de cálculo de Excel.
# Las bases de datos suelen contener varias tablas, cada una diseñada para un propósito específico. Por ejemplo, imagine la creación de una tabla de base de datos de nombres y números de teléfono .
#
# Primero, configuraríamos columnas con los títulos FirstName , LastName y TelephoneNumber .
# Cada tabla incluye su propio conjunto de campos, según los datos que almacenará.
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# #### Primary Keys
# Una clave primaria es un campo de la tabla que identifica de forma exclusiva los registros de la tabla.
#
# Principales características de `Primary key`:
# * Debe contener un **valor único** para cada fila
# * No puede contener valores **NULOS**
#
# Por ejemplo, en nuestra tabla contiene un registro para cada nombre en una libreta de teléfonos. El único de IDENTIFICACIÓN número sería una buena opción para una clave principal en la tabla, ya que siempre existe la posibilidad de más de una persona tiene el mismo nombre.
#
# ![imagen.png](attachment:imagen.png)

# %% [markdown]
# ### Instrucciones SQL: SELECT

# %% [markdown]
# #### Órdenes básicas de SQL
# La declaración SQL `SHOW` muestra la información contenida en la base de datos y sus tablas.
# Permite hacer seguimiento a los contenidos de BD y recuerda la de las tablas.
#
# * Por ejemplo, el comando **`SHOW DATABASES`** lista la bases de datos manejadas por el servidor. <br>
# > SHOW DATABASES
#
# * El comando **`SHOW TABLES`** es utilizado para mostrar todas las tablas en la base de datos en MYSQL.
# ![imagen.png](attachment:imagen.png)
#
#     Para nuestro ejemplo, hemos creado una base de datos, **my_database**, con una tabla llamada **customers**.
#
# * **`SHOW COLUMNS`** muestra información acerca de las columnas en una tabla dada.<br>
# El siguiente ejemplo muestra las columnas en nuestra tabla **customers**<br>
# > **SHOW COLUMNS FROM** customers
#
# <img src="Pictures/Columnas-Tablas.PNG"  style="width: 300px;"/> <br><br>
# * `SHOW COLUMNS` muestra los siguientes valores para cada uno de los valores de la tabla.
#
#     - **Field:** Nombre de la columna
#     - **Type:** Tipo de dato de la columna
#     - **Key:** Indica si la columna esta indexada
#     - **Default:** Valor por defecto asignado a la columna
#     - **Extra**: Puede contener cualquier información adicional que este disponible acerca de una columna dada.
#
# * La declaración **`SELECT`** es utilizado para seleccionar datos de una BD. El resultado es almacenado en una tabla resultante, la cual es llamada el **conjunto resultante**.<br>
# Una **query(consulta)**  Puede recuperar información de columnas seleccionadas o de todas las columnas en la tabla<br><br>
# **Sintaxis de la declaración SQL SELECT:**<br>
# > **SELECT** column_list <br>
# **FROM** table_name
#
#     - **column_list** incluye una o más listas de las cuales los datos son recuperados.
#     - **table_name** Es el nombre de la tabla de la cual la información es reccuperada.
#
# **Datos desde la tabla Customers:**
# <img src = "Pictures/tabla-customers.PNG" style = "width: 300px"/> <br>
#
# **Comando:**<br>
# > SELECT FirsName FROM customers <br>
#
# <img src = "Pictures/select-column.PNG" style = "width: 200px" title = "Devuelve columna FirstName" />   <br>
# Una declaración **SELECT** devuelve cero o más filas de una o más tablas.

# %% [markdown]
# Crear un nuevo usuario y otorgarle permisos
# https://www.digitalocean.com/community/tutorials/crear-un-nuevo-usuario-y-otorgarle-permisos-en-mysql-es
