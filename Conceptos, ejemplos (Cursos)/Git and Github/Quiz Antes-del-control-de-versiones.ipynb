# %% [markdown]
# # Prueba Practica: Antes del control de versiones

# %% [markdown]
# 1. Su colega le envió un parche llamado `fix_names.patch`, que corrige un archivo de configuración llamado `fix_names.conf`. ¿Qué comando necesita ejecutar para aplicar el parche al archivo de configuración?
#
# ![imagen.png](attachment:imagen.png)
# * El comando patch con el archivo que se va a parchear, seguido del nombre de archivo del parche, lo aplicará.

# %% [markdown]
# 2. Estás ayudando a un amigo con un error en un script llamado `fix_permissions.py`, que corrige los permisos de un montón de archivos. Para trabajar en el archivo, realice una copia y llámela `fix_permissions_modified.py`. ¿Qué comando necesitas ejecutar después de resolver el error para enviar el parche a tu amigo?
# ![imagen.png](attachment:imagen.png)
#     - El comando diff nos permitirá comparar y aplicar las diferencias entre los archivos.<br>
#
# 3. El comando `wdiff` supera las palabras que cambiaron en un archivo en lugar de trabajar línea por línea.
#     - El comando wdiff resalta las palabras que cambiaron en un archivo por color, además de trabajar línea por línea.

# %% [markdown]
# 4. ¿Cómo podemos elegir el valor devuelto que devuelve nuestro script cuando finaliza?
# ![imagen.png](attachment:imagen.png)
#     - Un script puede usar sys.exit para finalizar el procesamiento y devolver el número pasado como argumento como código de retorno del script.

# %% [markdown]
# 5. Además de los archivos originales, ¿qué más necesitamos antes de poder usar el comando patch?
# ![imagen.png](attachment:imagen.png)
#
#     - Necesitamos usar el comando patch con el archivo diff para aplicar nuevos cambios al archivo original.
