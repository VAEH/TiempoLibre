# %%
import scipy.stats
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
df = pd.read_csv('bicicletas-compartidas.csv')

# %% [markdown]
# Categoricas

# %%
df.columns
# Out:
# Index(['fecha', 'bicis-compartidas', 'temp-obs', 'sens-temp', 'hum', 'viento',
#        'codigo-clima', 'festivo', 'findesemana', 'cuartil-ano'],
#       dtype='object')

# %%
y = df['cuartil-ano'].apply(lambda x: 'cuartil-' + str(int(x)))

# %%
#Figuras y ejes
fig, ax = plt.subplots()
#Diagrama de barra, prsentamos un conteo y pedimos el index del nombre de las barras y luego pedimos value-count para la altura de las barras
ax.bar(y.value_counts().index, y.value_counts())
ax.set_xlabel('Cuatiles del año')
ax.set_ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %%
fig, ax = plt.subplots()
ax.bar(y.value_counts().index, y.value_counts())
ax.set_xlabel('Cuatiles del año')
ax.set_ylabel('Frecuencia')
#Se utiliza para darle color a la barra
ax.patches[2].set_facecolor('red')

# %%
fig, ax = plt.subplots()
#Se utiliza para realizar el diagrama de Pie y se agrega porcentaje dentro de la visualización. 
ax.pie(y.value_counts(), labels = y.value_counts().index, autopct='%1.1f%%')
ax.set_title('Diagrama de pie')
# Out:
# Text(0.5, 1.0, 'Diagrama de pie')

# %% [markdown]
# Numericas

# %%
#Definición de la variable que queremos como variable númerica. 
y = df['viento']

# %%
#definimos el sigueinte gráfico
fig, ax = plt.subplots()
#Histograma, en el que queremos contar las frecuencias asociadas a esta variable, pasamos la variable "y"
#Agregamos unos bins, que quiere decir: En cuantas particiones queremos dividir está variable continua. 
ax.hist(y, bins = 30)
ax.set_xlabel('Viento')
ax.set_ylabel('Frecuencias')
#Agregamos la función de una recta que mostrara el promedio
#Va hacer de color "r" rojo y una linea punteada
plt.axvline(np.mean(y), c = 'r', linestyle = '--', label = 'Promedio')
#Calculamos la desviación Estandar
plt.axvline(np.mean(y)+np.std(y), c = 'k', linestyle = '--', label = '+ 1-desviacion')
plt.axvline(np.mean(y)-np.std(y), c = 'k', linestyle = '--', label = '- 1-desviacion')
#Agrega el cuadrito con el nombre de las variables. 
ax.legend()

# %% [markdown]
# El diagrama de caja o boxplot es un método estandarizado para representar gráficamente una serie de datos numéricos a través de sus cuartiles. De esta manera, el diagrama de caja muestra a simple vista la mediana y los cuartiles de los datos,​ pudiendo también representar los valores atípicos de estos.
#
# El diagrama de caja es compuesto de los siguientes elementos:
# - Rango (sin datos atípicos)
# - Datos atípicos.
# - Rango intercuartil (también conocido como RIC)
# - Cuartiles (denotados como Q1, Q2 y Q3)
# - Mediana (Q2)
# - Mínimo y máximo.
#
# ##### Utilidad
#
# - Proporcionan una visión general de la simetría de la distribución de los datos; si la mediana no está en el centro del rectángulo, la distribución no es simétrica.
# - Son útiles para ver la presencia de valores atípicos también llamados outliers.
# - Pertenece a las herramientas de las estadística descriptiva. Permite ver como es la dispersión de los puntos con la mediana, los percentiles 25 y 75 y los valores máximos y mínimos.
#
# Ponen en una sola dimensión los datos de un histograma, facilitando así el análisis de la información al detectar que el 50% de la población está en los límites de la caja

# %%
#Realizmaos un diagrama de caja
fig, ax = plt.subplots()
#sns es un complemento adicional de matploit
sns.boxplot(x = 'cuartil-ano', y = 'bicis-compartidas', data = df )
# Out:
# <AxesSubplot:xlabel='cuartil-ano', ylabel='bicis-compartidas'>

# %% [markdown]
# #### Diagrama de Dispersión
# Un diagrama de dispersión o gráfica de dispersión o gráfico de burbujas es un tipo de diagrama matemático que utiliza las coordenadas cartesianas para mostrar los valores de dos variables para un conjunto de datos.
#
# Sirve basicamente para identificar el tipo de relación (si existe) entre dos variables cuantitativas.
#
# Si existe un parámetro que se incrementa o disminuye de forma sistemática por el experimentador, se le denomina parámetro de control o variable independiente y habitualmente se representa a lo largo del eje horizontal (eje de las abscisas). La variable medida o dependiente usualmente se representa a lo largo del eje vertical (eje de las ordenadas). Si no existe una variable dependiente, cualquier variable se puede representar en cada eje y el diagrama de dispersión mostrará el grado de correlación (no causalidad) entre las dos variables.

# %%
fig, ax = plt.subplots()
ax.scatter( df['viento'], df['bicis-compartidas'] , alpha = 0.03 )
ax.set_title('Distribucion conjunta de Viento y Bicis-Compartidas')
ax.set_xlabel('Viento')
ax.set_ylabel('Bicis-Compartidas')
# Out:
# Text(0, 0.5, 'Bicis-Compartidas')
